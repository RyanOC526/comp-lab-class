# %%
import numpy as np
import matplotlib.pyplot as plt
import os 

os.chdir('/home/rmo302/compclass/comp-lab-class/Week3/Data')

x1,y1 = np.loadtxt('rmsd_50.xvg', comments = "#", unpack = True)
x2,y2 = np.loadtxt('rmsd_50_xtal.xvg', comments = '#', unpack = True)

plt.plot(x1,y1, label = "Equilibrated")
plt.plot(x2,y2, label = "Crystal")

plt.title("RMSD: 1AKI, Backbone")
plt.xlabel("Time (ns)")
plt.ylabel("RMSD (nm)")

plt.legend()

plt.show()

plt.savefig('/home/rmo302/compclass/comp-lab-class/Week3/Figures/RMSD 1AKI_50ns.pdf')

# %%
x1,y1, a,b,c = np.loadtxt('gyrate_50.xvg', comments = "#", unpack = True)

plt.plot(x1,y1)

plt.title("Radius of Gyration: 1AKI, Unrestrained MD")
plt.xlabel("Time (ns)")
plt.ylabel("Rg (nm)")

plt.show()

plt.savefig('/home/rmo302/compclass/comp-lab-class/Week3/Figures/Gyrate 1AKI_50ns.pdf')

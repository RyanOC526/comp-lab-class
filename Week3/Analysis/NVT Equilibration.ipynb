# %%
import numpy as np
import matplotlib.pyplot as plt
import os 

os.chdir('/home/rmo302/compclass/comp-lab-class/Week3/Data')

x,y = np.loadtxt('temperature.xvg', comments = "#", unpack = True)
plt.plot(x,y)

plt.title("Temperature: 1AKI, NVT Equilibration")
plt.xlabel("Time (ps)")
plt.ylabel("Temperature (K)")

plt.show()

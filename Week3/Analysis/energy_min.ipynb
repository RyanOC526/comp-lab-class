# %%
import numpy as np
import matplotlib.pyplot as plt
import os 

os.chdir('/home/rmo302/compclass/comp-lab-class/Week3/Data')

x1,y1 = np.loadtxt('potential.xvg', comments = "#", unpack = True)

plt.plot(x1,y1, label = "Potential")

plt.title("Energy Minimization: 1AKI Steepest Descent")
plt.xlabel("Energy Minimization Step")
plt.ylabel("Potential Energy (kJ/mol)")

plt.legend()

plt.show()

plt.savefig('/home/rmo302/compclass/comp-lab-class/Week3/Figures/Energy Minimization.pdf')

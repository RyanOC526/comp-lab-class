# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md
import os

# %%
os.chdir("/home/rmo302/compclass/comp-lab-class/Week4/Setup/Ions/NaCl_CHARMM36M/gromacs")

traj = md.load_xtc('step5_nowater.xtc', top = "step5_nowater.gro")

x1,y1 = np.loadtxt('step5_msd_waterO.xvg', comments = "#", unpack = True)
x2,y2 = np.loadtxt('step5_msd_Na.xvg', comments = '#', unpack = True)
x3,y3 = np.loadtxt('step5_msd_Cl.xvg', comments = '#', unpack = True)

plt.plot(x1,y1, label = "Water Oxygens")
plt.plot(x2,y2, label = "Sodium")
plt.plot(x3,y3, label = 'Chlorine')

plt.title('Mean Square Distance For Specified Atoms')
plt.xlabel("Time (ps)")
plt.ylabel("MSD (nm^2")

plt.legend()

plt.show()

plt.savefig('/home/rmo302/compclass/comp-lab-class/Week4/Figures/Mean Square Distance.pdf')

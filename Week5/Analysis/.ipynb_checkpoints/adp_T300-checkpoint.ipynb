# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import mdtraj as md

# %%
#computes phi and psi dihedral angles

os.chdir('/home/rmo302/compclass/comp-lab-class/Week5/T300')

traj = md.load("adp_exchange4temps.trr", top = "adp_exchange4temps.gro")

phi = md.compute_phi(traj, periodic = True, opt = True)
psi = md.compute_psi(traj, periodic = True, opt = True)

# %%
hist = np.histogram2d(phi[1][:,0], psi[1][:,0])

energy = -np.log(hist[0].T)

plt.imshow(energy, extent = [hist[1][0], hist[1][-1], hist[2][0], hist[2][-1]], 
           origin = 'lower')
plt.colorbar()
plt.title("Free Energy Surface")
plt.xlabel('Phi (Radians)')
plt.ylabel('Psi (Radians)')
# Out:
# /state/partition1/job-26175095/ipykernel_113175/3257481270.py:3: RuntimeWarning: divide by zero encountered in log
#   energy = -np.log(hist[0].T)
# Text(0, 0.5, 'Psi (Radians)')

# %%
#plotting replica 

x,y1, y2, y3, y4 = np.loadtxt("replica_temp.xvg", unpack = True)

plt.plot(x[::500], y1[::500], label = '300 K')
plt.plot(x[::500], y2[::500], label = '350 K')
plt.plot(x[::500], y3[::500], label = '400 K')
plt.plot(x[::500], y4[::500], label = '450 K')

plt.xlabel('Time (ps)')
plt.legend()
plt.show()

# %%
# Potential energy histogram

os.chdir('/home/rmo302/compclass/comp-lab-class/Week5/T300')

x1,y1 = np.loadtxt('potential_300.xvg', unpack = True)

hist1 = np.histogram2d(x1, y1)

os.chdir('/home/rmo302/compclass/comp-lab-class/Week5/T350')

x2,y2 = np.loadtxt('potential_350.xvg', unpack = True)

hist2 = np.histogram2d(x2, y2)

os.chdir('/home/rmo302/compclass/comp-lab-class/Week5/T400')

x3,y3 = np.loadtxt('potential_400.xvg', unpack = True)

hist3 = np.histogram2d(x3, y3)

os.chdir('/home/rmo302/compclass/comp-lab-class/Week5/T450')

x2,y2 = np.loadtxt('potential_350.xvg', unpack = True)

hist2 = np.histogram2d(x2, y2(x2, y2)

plt.plot(hist1, hist2, hist3, hist4)
# Out:
# /ext3/miniconda3/lib/python3.9/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [35], in <cell line: 21>()
#      17 os.chdir('/home/rmo302/compclass/comp-lab-class/Week5/T450')
#      19 hist4 = np.loadtxt('potential_450.xvg')
# ---> 21 plt.plot(hist1, hist2, hist3, hist4)
#
# File /ext3/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2767, in plot(scalex, scaley, data, *args, **kwargs)
#    2765 @_copy_docstring_and_deprecators(Axes.plot)
#    2766 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
#    2769         **({"data": data} if data is not None else {}), **kwargs)
#
# File /ext3/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1635, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1393 """
#    1394 Plot y versus x as lines and/or markers.
#    1395
#    (...)
#    1632 (``'green'``) or hex strings (``'#008000'``).
#    1633 """
#    1634 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636 for line in lines:
#    1637     self.add_line(line)
#
# File /ext3/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File /ext3/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     495     self.axes.yaxis.update_units(y)
#     497 if x.shape[0] != y.shape[0]:
# --> 498     raise ValueError(f"x and y must have same first dimension, but "
#     499                      f"have shapes {x.shape} and {y.shape}")
#     500 if x.ndim > 2 or y.ndim > 2:
#     501     raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (3,) and (501, 2)
